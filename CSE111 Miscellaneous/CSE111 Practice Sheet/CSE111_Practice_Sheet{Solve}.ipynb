# %%
#Task - 01
class PlayerEarning :
  def __init__ (self, name) :
    self.name = name
    self.salary = 0
    self.bonus = 0
  def calculateTotal(self, salary, goal=0) :
    self.salary = salary
    if goal > 30 :
      self.bonus = (5/100)*self.salary+10000
    elif goal == 0 :
      self.bonus = 0
    else :
      self.bonus = (5/100)*self.salary
  def printDetails(self) :
    print(f"Player Name: {self.name}")
    print(f"Player Season Earning without bonus: {self.salary}")
    print(f"Bonus = {int(self.bonus)}")
    print(f"Player Season Earning After Bonus: {int(self.bonus+self.salary)}")
print("**********************")
player1 = PlayerEarning('Buffon')
player1.calculateTotal(250000)
player1.printDetails()

print("\n**********************")
player2 = PlayerEarning('Dybala')
player2.calculateTotal(250000, 31)
player2.printDetails()

print("\n**********************")
player3 = PlayerEarning('Cuadrado')
player3.calculateTotal(250000, 20)
player3.printDetails()
# Out:
# **********************
# Player Name: Buffon
# Player Season Earning without bonus: 250000
# Bonus = 0
# Player Season Earning After Bonus: 250000
#
# **********************
# Player Name: Dybala
# Player Season Earning without bonus: 250000
# Bonus = 22500
# Player Season Earning After Bonus: 272500
#
# **********************
# Player Name: Cuadrado
# Player Season Earning without bonus: 250000
# Bonus = 12500
# Player Season Earning After Bonus: 262500

# %%
#Task - 02
class myList :
  def __init__ (self, *args) :
    self.list = list(args)
  def sum (self) :
    sum = 0
    for index in range(len(self.list)) :
      sum += self.list[index]
    print("Sum:",sum)
  def merge(self, *args) :
    for index in range(len(args)) :
      self.list.append(args[index])
  def average(self) :
    if len(self.list) == 0 :
      print("Average:",0)
    else :
      sum = 0
      for index in range(len(self.list)) :
        sum += self.list[index]
      print("Average:",sum/len(self.list))
l1 =  myList(2,3,4,5,6) #you might need a list inside your class to store the values
l1.sum()
l1.merge(4,5,9)
l1.sum()
l1.average()
print("-----------------------------")
l2 =  myList()
l2.average()
l2.merge(1,2,4,8)
l2.sum()
# Out:
# Sum: 20
# Sum: 38
# Average: 4.75
# -----------------------------
# Average: 0
# Sum: 15

# %%
#Task - 03
class Bird :
  def __init__(self, name, status= False) :
    self.name = name
    self.status = status
    self.__type = "Flightless Birds"
  def fly(self) :
    if self.status == False :
      print(f"{self.name} can not fly")
    else :
      print(f"{self.name} can fly")
  def setType(self, status) :
    self.__type = status
  def getType(self) :
    return self.__type
  def printDetail(self) :
    print(f"Name: {self.name}")
    print(f"Type: {self.getType()}")
ostrich = Bird('Ostrich')
duck = Bird("Duck", True)
owl = Bird('Owl', True)
print("###########################")
ostrich.fly()
duck.fly()
owl.fly()
duck.setType('Water Birds')
owl.setType('Birds of Prey')
print("=========================")
ostrich.printDetail()
print("=========================")
duck.printDetail()
print("=========================")
owl.printDetail()
# Out:
# ###########################
# Ostrich can not fly
# Duck can fly
# Owl can fly
# =========================
# Name: Ostrich
# Type: Flightless Birds
# =========================
# Name: Duck
# Type: Water Birds
# =========================
# Name: Owl
# Type: Birds of Prey

# %%
#Task - 04
class Account :
  count = 0
  def __init__(self, name, age, prof, salary) :
    self.name, self.age, self.profession, self.balance = name, age, prof, salary
    Account.count += 1
  def addMoney (self, value) :
    self.balance += value
  def withdrawMoney(self, value) :
    if self.balance - value >= 0 :
      self.balance -= value
    else :
      pass
  def printDetails(self) :
    print(f"Name: {self.name}")
    print(f"Age: {self.age}")
    print(f"Occupation: {self.profession}")
    print(f"Total Amount: {self.balance}")

# Write your code here

print('No of account holders:', Account.count)
print("=========================")
p1 = Account("Abdul", 45, "Service Holder", 500000)
p1.addMoney(300000)
p1.printDetails()
print("=========================")
p2 = Account("Rahim", 55, "Businessman", 700000)
p2.withdrawMoney(700000)
p2.printDetails()
print("=========================")
p3 = Account("Ashraf", 62, "Govt. Officer", 200000)
p3.withdrawMoney(250000)
p3.printDetails()
print("=========================")
print('No of account holders:', Account.count)
# Out:
# No of account holders: 0
# =========================
# Name: Abdul
# Age: 45
# Occupation: Service Holder
# Total Amount: 800000
# =========================
# Name: Rahim
# Age: 55
# Occupation: Businessman
# Total Amount: 0
# =========================
# Name: Ashraf
# Age: 62
# Occupation: Govt. Officer
# Total Amount: 200000
# =========================
# No of account holders: 3

# %%
#Task - 05
class Smartphone :
    def __init__(self, name = None) :
        self.name = name
        self.feature = {}
    def addFeature(self, parts, spec) :
        if self.name == None :
            print(f"Feature can not be added without phone name")
        else :
            if parts in self.feature.keys() :
                self.feature[parts].append(spec)
            else :
                self.feature[parts]=[]
                self.feature[parts].append(spec)
    def setName (self, name) :
        self.name = name
    def printDetail(self) :
        print(f"Phone Name: {self.name}")
        for key, value in self.feature.items() :
            print(f"{key}: {','.join(value)}")
s1 = Smartphone()
print("=================================")
s1.addFeature("Display", "6.1 inch")
print("=================================")
s1.setName("Samsung Note 20")
s1.addFeature("Display", "6.1 inch")
s1.printDetail()
print("=================================")
s2 = Smartphone("Iphone 12 Pro")
s2.addFeature("Display", "6.2 inch")
s2.addFeature("Ram", "6 GB")
print("=================================")
s2.printDetail()
s2.addFeature("Display", "Amoled panel")
s2.addFeature("Ram", "DDR5")
print("=================================")
s2.printDetail()
print("=================================")
# Out:
# =================================
# Feature can not be added without phone name
# =================================
# Phone Name: Samsung Note 20
# Display: 6.1 inch
# =================================
# =================================
# Phone Name: Iphone 12 Pro
# Display: 6.2 inch
# Ram: 6 GB
# =================================
# Phone Name: Iphone 12 Pro
# Display: 6.2 inch,Amoled panel
# Ram: 6 GB,DDR5
# =================================

# %%
#Task - 06
class Student :
    total = 0
    department_count = {'CSE' : 0, 'BBA': 0}
    CSE = 0
    BBA = 0
    def __init__ (self, name, dept) :
        self.name , self.department = name, dept
        Student.total += 1
        if self.department == 'CSE' :
            Student.CSE += 1
            self.count = Student.CSE
        else :
            Student.BBA += 1
            self.count = Student.BBA
        
        print(f"Creating Student Number: {Student.total}")
        Student.department_count[self.department] += 1
    def individualInfo(self) :
        print(f"{self.name} is from {self.department} department")
        print(f"Serial of {self.name} among all students' is: {Student.total}")
        print(f"Serial of {self.name} in {self.department} department is: {self.count}")
    def totalInfo(self) :
        print(f"Total Number of Student: {Student.total}")
        for key, value in Student.department_count.items() :
            print(f"Total Number of {key} Student: {value}")

s1 = Student("Naruto", "CSE")
print('----------------------')
s1.individualInfo()
print('#############################')
s1.totalInfo()
print('============================')


s2 = Student("Sakura", "BBA")
print('----------------------')
s2.individualInfo()
print('#############################')
s2.totalInfo()
print('============================')

s3 = Student("Shikamaru", "CSE")
print('----------------------')
s3.individualInfo()
print('#############################')
s3.totalInfo()
print('============================')


s4 = Student("Deidara", "BBA")
print('----------------------')
s4.individualInfo()
print('#############################')
s4.totalInfo()
# Out:
# Creating Student Number: 1
# ----------------------
# Naruto is from CSE department
# Serial of Naruto among all students' is: 1
# Serial of Naruto in CSE department is: 1
# #############################
# Total Number of Student: 1
# Total Number of CSE Student: 1
# Total Number of BBA Student: 0
# ============================
# Creating Student Number: 2
# ----------------------
# Sakura is from BBA department
# Serial of Sakura among all students' is: 2
# Serial of Sakura in BBA department is: 1
# #############################
# Total Number of Student: 2
# Total Number of CSE Student: 1
# Total Number of BBA Student: 1
# ============================
# Creating Student Number: 3
# ----------------------
# Shikamaru is from CSE department
# Serial of Shikamaru among all students' is: 3
# Serial of Shikamaru in CSE department is: 2
# #############################
# Total Number of Student: 3
# Total Number of CSE Student: 2
# Total Number of BBA Student: 1
# ============================
# Creating Student Number: 4
# ----------------------
# Deidara is from BBA department
# Serial of Deidara among all students' is: 4
# Serial of Deidara in BBA department is: 2
# #############################
# Total Number of Student: 4
# Total Number of CSE Student: 2
# Total Number of BBA Student: 2

# %%
#Task - 07
class book:
    def __init__(self, name):
        self.name = name
        self.genre='biography'
    def review(self):
         print('This book is just out of the world,mind-blowing!')
class fiction(book) :
    def __init__(self, name, genre=None) :
        super().__init__(name)
        self.genre = genre
    def review (self) :
        print(f"{self.name} which is a {self.genre} is just out of the world, mind-blowing!")
class nonfiction(book) :
    def __init__(self, name) :
        super().__init__(name)
    def review (self) :
        print(f"{self.name} which is a {self.genre} is just out of the world, mind-blowing!")
# Write your code here        

b1 = fiction('The Shining','Psychological horror')
b2 = nonfiction('A Beautiful Mind')
b1.review()
print('=========================')
b2.review()
print('=========================')
# Out:
# The Shining which is a Psychological horror is just out of the world, mind-blowing!
# =========================
# A Beautiful Mind which is a biography is just out of the world, mind-blowing!
# =========================

# %%
#Task - 08
class Processor:
    def __init__(self, model, thread, core):
        self.model = model
        self.core = core
        self.thread = thread
    def getInfo(self):
        return "Model: "+self.model+ "\nCores: "+str(self.core)+ "\nThreads: "+ str(self.thread) 
# Write your code here
class Intel (Processor) :
    def __init__(self, model, core, thread, price) :
        super().__init__(model, thread, core) 
        self.price = price
    def getInfo(self) :
        print(super().getInfo())
        print(f"Price: {self.price} taka")
class AMD (Processor) :
    def __init__(self, model, core, thread, price) :
        super().__init__(model, thread, core) 
        self.price = price
    def getInfo(self) :
        print(super().getInfo())
        print(f"Price: {self.price} taka")
p1 = Intel("Intel i5 10th Gen",6,12,17000) 
p2 = AMD("Ryzen 5 3500X",6,6,13800)
p3 = AMD("Ryzen 5 3600",6,12,16900)
print('======================')
p1.getInfo()
print('======================')
p2.getInfo()
print('======================')
p3.getInfo()
# Out:
# ======================
# Model: Intel i5 10th Gen
# Cores: 6
# Threads: 12
# Price: 17000 taka
# ======================
# Model: Ryzen 5 3500X
# Cores: 6
# Threads: 6
# Price: 13800 taka
# ======================
# Model: Ryzen 5 3600
# Cores: 6
# Threads: 12
# Price: 16900 taka

# %%
#Task - 09
class Fruit:
    Total_order=0
    
    def __init__(self, Order_ID, weight):
        self.Order_ID=Order_ID
        self.weight=weight
        Fruit.Total_order=Fruit.Total_order+1
    
    def __str__(self):
        return self.Order_ID+", Weight: "+str(self.weight)

class Mango(Fruit):
     #write your code here
    def __init__(self, ID, weight, name, unit_price) :
        super().__init__(ID, weight)
        self.name = name
        self.price = unit_price* self.weight
    def __str__(self) :
        return(f"{super().__str__()}, Variety: {self.name}, Total Price: {self.price}")
    def __add__(self, other) :
        return f"The total Price of the orders are: {self.price + other.price}"


class JackFruit(Fruit):
      #write your code here
      def __init__(self, id, weight, unit_price) :
          super().__init__(id, weight)
          self.price = unit_price * self.weight
      def __str__(self) :
          return f"{super().__str__()}, Total Price: {self.price}"
      def __add__(self, other) :
        return f"The total Price of the orders are: {self.price + other.price}"
    
m1=Mango("Order Id 1", 5,"GopalVog",250)
print(m1)
m2=Mango("Order Id 2", 5,"HariVanga", 230)
print(m2) 
j1=JackFruit("Order Id 3", 5,250)
print(j1)
j2=JackFruit("Order Id 4", 4,210)
print(j2)
print("Total number of Orders: "+str(Fruit.Total_order))
print("==================")
print(m1+m2)
print("==================")
print(j1+j2)
# Out:
# Order Id 1, Weight: 5, Variety: GopalVog, Total Price: 1250
# Order Id 2, Weight: 5, Variety: HariVanga, Total Price: 1150
# Order Id 3, Weight: 5, Total Price: 1250
# Order Id 4, Weight: 4, Total Price: 840
# Total number of Orders: 4
# ==================
# The total Price of the orders are: 2400
# ==================
# The total Price of the orders are: 2090

# %%
#Task - 10
class Student:
    def __init__(self,name,ID):
        self.name = name
        self.ID = ID
    def Details(self):
        return "Name: "+self.name+"\n"+"ID: "+self.ID+"\n"
#Write your code here
class CSEStudent(Student):
    def __init__(self,name, id, semester) :
        super().__init__(name, id) 
        self.semester = semester
        self.course = {}
    def Details(self) :
        return f"{super().Details()}Current Semester: {self.semester}"
    def addCourseWithMarks(self, *args ) :
        for index in range(0, len(args), 2 ) :
            if args[index+1] >= 85 :
                self.course[args[index]] = 4.0
            elif args[index+1] >= 80 :
                self.course[args[index]] = 3.3
            elif args[index+1] >= 70 :
                self.course[args[index]] = 3.0
            elif args[index+1] >= 65 :
                self.course[args[index]] = 2.3
            elif args[index+1] >= 57 :
                self.course[args[index]] = 2.0
            elif args[index+1] >= 55 :
                self.course[args[index]] = 1.3
            elif args[index+1] >= 50 :
                self.course[args[index]] = 1.0
            else :
                self.course[args[index]] = 0.0
    def showGPA(self) :
        gpa = 0
        for key, value in self.course.items() :
            gpa += value
            print(f"{key}: {value}")
        gpa /= len(self.course.values())
        print(f"GPA of {self.name} is: {round(gpa, 2)}")
    
                
Bob = CSEStudent("Bob","20301018","Fall 2020")
Carol = CSEStudent("Carol","16301814","Fall 2020")
Anny = CSEStudent("Anny","18201234","Fall 2020")
print("#########################")
print(Bob.Details())
print("#########################")
print(Carol.Details())
print("#########################")
print(Anny.Details())
print("#########################")
Bob.addCourseWithMarks("CSE111",83.5,"CSE230",73.0,"CSE260",92.5)
Carol.addCourseWithMarks("CSE470",62.5,"CSE422",69.0,"CSE460",76.5,"CSE461",87.0)
Anny.addCourseWithMarks("CSE340",45.5,"CSE321",95.0,"CSE370",91.0)
print("----------------------------")
Bob.showGPA()
print("----------------------------")
Carol.showGPA()
print("----------------------------")
Anny.showGPA()
# Out:
# #########################
# Name: Bob
# ID: 20301018
# Current Semester: Fall 2020
# #########################
# Name: Carol
# ID: 16301814
# Current Semester: Fall 2020
# #########################
# Name: Anny
# ID: 18201234
# Current Semester: Fall 2020
# #########################
# ----------------------------
# CSE111: 3.3
# CSE230: 3.0
# CSE260: 4.0
# GPA of Bob is: 3.43
# ----------------------------
# CSE470: 2.0
# CSE422: 2.3
# CSE460: 3.0
# CSE461: 4.0
# GPA of Carol is: 2.83
# ----------------------------
# CSE340: 0.0
# CSE321: 4.0
# CSE370: 4.0
# GPA of Anny is: 2.67

# %%
#Task - 11
class Transport:
    total_traveller = 0
    
    def __init__(self, name, fare):
        self.name = name
        self.baseFare = fare
    
    def __str__(self):
        s =  "Name: "+self.name+", Base fare: "+str(self.baseFare)
        return s
class Bus (Transport) :
    def __init__(self, name, fare) :
        super().__init__(name, fare) 
        self.count = 0
        self.passanger_details = {}
        print(f"Base-fare of {self.name} is {self.baseFare} Taka")
    def addPassengerWithBags(self, *args) :

        for index in range(0, len(args), 2) :
            if args[index+ 1] <= 2 :
                self.passanger_details[args[index]] = self.baseFare
            elif args[index+1] <=5 :
                self.passanger_details[args[index]] = self.baseFare+60
            else :
                self.passanger_details[args[index]] = self.baseFare+105
            Transport.total_traveller += 1
    def __str__(self) :
        print(super().__str__()) 
        print(f"Total Passenger(s): {len(self.passanger_details.values())}")
        index = -1
        for key, value in self.passanger_details.items() :
            index += 1
            if index+1 == len(self.passanger_details.keys()):
                return f"Name: {key}, Fare: {value}"
            else :
                print(f"Name: {key}, Fare: {value}")
        
class Train(Transport) :
    def __init__(self, name, fare) :
        super().__init__(name, fare) 
        self.count = 0
        self.passanger_details = {}
        print(f"Base-fare of {self.name} is {self.baseFare} Taka")     
    def addPassengerWithBags(self, *args) :

        for index in range(0, len(args), 2) :
            if args[index+ 1] <= 2 :
                self.passanger_details[args[index]] = self.baseFare
            elif args[index+1] <=5 :
                self.passanger_details[args[index]] = self.baseFare+60
            else :
                self.passanger_details[args[index]] = self.baseFare+105
            Transport.total_traveller += 1  
    def __str__(self) :
        print(super().__str__()) 
        print(f"Total Passenger(s): {len(self.passanger_details.values())}")
        index = 0
        for key, value in self.passanger_details.items() :
            index += 1
            if index == len(self.passanger_details.keys()):
                return f"Name: {key}, Fare: {value}"
            print(f"Name: {key}, Fare: {value}")        
# Write your codes here.
# Do not change the following lines of code.
t1 = Bus("Volvo", 950)
print("=================================")
t1.addPassengerWithBags("David", 6,  "Mike", 1, "Carol", 3)
print("=================================")
print(t1)
print("=================================")
t2 = Train("Silk City", 850)
print("=================================")
t2.addPassengerWithBags("Bob", 2, "Simon", 4)
print("=================================")
print(t2)
print("=================================")
print("Total Passengers in Transport: ", Transport.total_traveller )
# Out:
# Base-fare of Volvo is 950 Taka
# =================================
# =================================
# Name: Volvo, Base fare: 950
# Total Passenger(s): 3
# Name: David, Fare: 1055
# Name: Mike, Fare: 950
# Name: Carol, Fare: 1010
# =================================
# Base-fare of Silk City is 850 Taka
# =================================
# =================================
# Name: Silk City, Base fare: 850
# Total Passenger(s): 2
# Name: Bob, Fare: 850
# Name: Simon, Fare: 910
# =================================
# Total Passengers in Transport:  5

# %%
# Task 12
class AppleProduct:
  def __init__(self, name, model, base_price):
    self.name = name
    self.model = model
    self.base_price = base_price
  def companyInfo(self):
    st = ("Company Name: Apple\nFouder: Steve Jobs, Steve Wozniak, Ronald Wayne\nCurrent CEO: Tim Cook\nAddress: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States")    
    return st
  def feature(self):
    st = (f"Name: {self.name}\nProduct Model: {self.model}\nHardware Quality: Excellent Hardwares\nGuarantee/ Warranty: Apple Care")
    return st
  def __str__(self):
    print('This is apple product.')
  def calculatePrice(self):
    print('Total Price:', self.base_price)
# Write your codes here.
class MacBookPro2020(AppleProduct) :
  def __init__(self, name, model, ram, chip, tax) :
    super().__init__(name, model,1299)
    self.ram = ram
    self.chip = chip
    self.tax = tax
    self.price = self.base_price
    self.base_price = self.base_price*(self.tax/100)+self.base_price
  def __str__(self) :
    print("Product Details:")
    print(super().feature())
    print(f"RAM: {self.ram}GB")
    print(f"Chip: {self.chip}")
    return(super().companyInfo())
    #return str(self.base_price)
  def calculatePrice(self):
    print(f"Calculating Price:\nBase Price: {self.price}")
    print(f"Tax: {self.tax}%")
    super().calculatePrice()
    return self.base_price
  def __add__(self, other) :
    return self.base_price + other.base_price
  
class iPhone12(AppleProduct) :
  def __init__(self, name, model, ram, chip, tax) :
    super().__init__(name, model,799)
    self.ram = ram
    self.chip = chip
    self.tax = tax
    self.price = self.base_price
    self.base_price = self.base_price*(self.tax/100)+self.base_price
  def __str__(self) :
    print("Product Details:")
    print(super().feature())
    print(f"RAM: {self.ram}GB")
    print(f"Chip: {self.chip}")
    return(super().companyInfo())
    #return str(self.base_price)
  def calculatePrice(self):
    print(f"Calculating Price:\nBase Price: {self.price}")
    print(f"Tax: {self.tax}%")
    super().calculatePrice()
    return self.base_price
  def __add__(self, other) :
    return self.base_price + other.base_price
# Do not change the following lines of code.

m1 = MacBookPro2020('MacBook', 'MacBookPro2020', 8, 'M1', 10)
print(m1)
print('====================================')
m1.calculatePrice()
print('###################################')
iphone = iPhone12('iPhone', 'iPhone 12', 8, 'A14', 5)
print(iphone)
print('====================================')
iphone.calculatePrice()  
print('###################################')
print('Total Price of these two products: ',end='')
print('%.2f Dollars'%(m1 + iphone))
# Out:
# Product Details:
# Name: MacBook
# Product Model: MacBookPro2020
# Hardware Quality: Excellent Hardwares
# Guarantee/ Warranty: Apple Care
# RAM: 8GB
# Chip: M1
# Company Name: Apple
# Fouder: Steve Jobs, Steve Wozniak, Ronald Wayne
# Current CEO: Tim Cook
# Address: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States
# ====================================
# Calculating Price:
# Base Price: 1299
# Tax: 10%
# Total Price: 1428.9
# ###################################
# Product Details:
# Name: iPhone
# Product Model: iPhone 12
# Hardware Quality: Excellent Hardwares
# Guarantee/ Warranty: Apple Care
# RAM: 8GB
# Chip: A14
# Company Name: Apple
# Fouder: Steve Jobs, Steve Wozniak, Ronald Wayne
# Current CEO: Tim Cook
# Address: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States
# ====================================
# Calculating Price:
# Base Price: 799
# Tax: 5%
# Total Price: 838.95
# ###################################
# Total Price of these two products: 2267.85 Dollars

# %%
# Task 13
class University:
	name  = "ABC University"
	numberOfStudents = 0
	admissionFee = 28000
	Library = 2000
	def __init__(self, n,i):
		self.stName = n
		self.stId = i
         	
	def payment(self):
		return self.admissionFee + self.Library
	
	def __str__(self):
		return "Student Name: {}, ID: {}\nFee: {}".format(self.stName, self.stId, self.payment())
class CSE_dept(University) :
	SemesterFee = 7700
	PerCreditFee = 6600
	LabFee = 2750
	def __init__(self, name, id, credit = 6) :
		super().__init__(name, id)
		University.numberOfStudents += 1
		self.no_of_credit = credit
		self.total = super().payment()+CSE_dept.SemesterFee+(CSE_dept.PerCreditFee*self.no_of_credit)+CSE_dept.LabFee
	def payment_details(self) :
		print("\nDETAILS:")
		print(f"Admission Fee: {University.admissionFee}")
		print(f"Library Fee: {University.Library}")
		print(f"Semester Fee: {CSE_dept.SemesterFee}\nPer Credit Fee: {CSE_dept.PerCreditFee}\nNumber of credits: {self.no_of_credit}\nLab Fee: {CSE_dept.LabFee}")
	def __str__ (self) :
		self.total = super().payment()+CSE_dept.SemesterFee+(CSE_dept.PerCreditFee*self.no_of_credit)+CSE_dept.LabFee
		return "Student Name: {}, ID: {}\nFee: {}".format(self.stName, self.stId, self.total)
	def __add__ (self, other) :
		return self.total + other.total
class PHR_dept(University) :
	SemesterFee = 11000
	PerCreditFee = 6600
	def __init__(self, name, id, credit = 9) :
		super().__init__(name, id)
		University.numberOfStudents += 1
		self.no_of_credit = credit
		self.total = super().payment()+PHR_dept.SemesterFee+(PHR_dept.PerCreditFee*self.no_of_credit)
	def payment_details(self) :
		print("\nDETAILS:")
		print(f"Admission Fee: {University.admissionFee}")
		print(f"Library Fee: {University.Library}")
		print(f"Semester Fee: {PHR_dept.SemesterFee}\nPer Credit Fee: {PHR_dept.PerCreditFee}\nNumber of credits: {self.no_of_credit}")
	def __str__ (self) :
		self.total = super().payment()+PHR_dept.SemesterFee+(PHR_dept.PerCreditFee*self.no_of_credit)
		return "Student Name: {}, ID: {}\nFee: {}".format(self.stName, self.stId, self.total)
	def __add__ (self, other) :
		return self.total + other.total
		
c1 = CSE_dept("Mary","5678")  
print(c1)
c1.payment_details()
print("===========================")
p1 = PHR_dept("Simon","91011")  
print(p1)
p1.payment_details()
print("===========================")
c2 = CSE_dept("Adam","1234", 12)  
print(c2)
c2.payment_details()
print("===========================")
p2 = PHR_dept("David","121314", 15)  
print(p2)
p2.payment_details()
print("===========================")
print("Total Number of Students:", University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2)) 
print("===========================")
print("Due to the pandemic, admission and library fees have been reduced for all departments. ")
University.admissionFee -= 1000
University.Library -= 100
print("The credit, semester and lab fees have been reduced for the CSE department. ")
CSE_dept.PerCreditFee -= 100
CSE_dept.SemesterFee -= 100
CSE_dept.LabFee -=100
print("The credit and semester fees have been reduced for the PHR department.\n ")
PHR_dept.PerCreditFee -= 100
PHR_dept.SemesterFee -= 1000
print(c1)
print(p1)
print(c2)
print(p2)
print("===========================")
print("Total Number of Students:", University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
# Out:
# Student Name: Mary, ID: 5678
# Fee: 80050
#
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# Per Credit Fee: 6600
# Number of credits: 6
# Lab Fee: 2750
# ===========================
# Student Name: Simon, ID: 91011
# Fee: 100400
#
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# Per Credit Fee: 6600
# Number of credits: 9
# ===========================
# Student Name: Adam, ID: 1234
# Fee: 119650
#
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# Per Credit Fee: 6600
# Number of credits: 12
# Lab Fee: 2750
# ===========================
# Student Name: David, ID: 121314
# Fee: 140000
#
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# Per Credit Fee: 6600
# Number of credits: 15
# ===========================
# Total Number of Students: 4
# Total University Revenue: 440100
# ===========================
# Due to the pandemic, admission and library fees have been reduced for all departments.
# The credit, semester and lab fees have been reduced for the CSE department.
# The credit and semester fees have been reduced for the PHR department.
#
# Student Name: Mary, ID: 5678
# Fee: 78150
# Student Name: Simon, ID: 91011
# Fee: 97400
# Student Name: Adam, ID: 1234
# Fee: 117150
# Student Name: David, ID: 121314
# Fee: 136400
# ===========================
# Total Number of Students: 4
# Total University Revenue: 429100

# %%
# Task 14
class Library:
    Total_book = 1000
    borrow_data = {}
    
    def __init__(self,n,id):
        self.student_name = n
        self.student_id = id     
    
    def borrowbook(self):
        print("A book is borrowed!")
        
    def __str__(self):
        return "Library: XYZ"
class Student(Library) :
    loc = []
    def __init__(self, name, id) :
        super().__init__(name, id)
        self.borrow = []
        self.book = []
        Student.loc.append(self)
    def borrowbook(self, book, id = None) :
        super().borrowbook()
        if id != None :
            status = True
            for index in range(len(Student.loc)) :
                if id in Student.loc[index].book :
                    status = False
                    location = Student.loc[index]
                    break
                else :
                    pass
            if status == True :
                print(f"'{book}' book with the unique id {id} is borrowed by {self.student_name}({self.student_id}) ")
                if book in Library.borrow_data.keys() :
                    Library.borrow_data[book].append(self.student_name)
                else :
                    Library.borrow_data[book]= [self.student_name]
                Library.Total_book -= 1
                self.borrow.append(book)
                self.book.append(id)
                print(f"Number of books available for borrowing = {Library.Total_book}")
            else :
                print(f"Sorry {self.student_name} ! {book} book is borrowed by {location.student_name}")
        else :
            print(f"'{book}' book is borrowed by {self.student_name}({self.student_id}) ")
            Library.Total_book -= 1
            self.borrow.append(book)
            print(f"Number of books available for borrowing = {Library.Total_book}")
            if book in Library.borrow_data.keys() :
                    Library.borrow_data[book].append(self.student_name)
            else :
                Library.borrow_data[book]= [self.student_name]
        
        
    def __str__(self) :
        print(super().__str__())
        print(f"Student Name: {self.student_name} ID: {self.student_id}")
        return f"Books borrowed: {', '.join(self.borrow)}"
    def returnAllBooks(self) :
        a = Library.borrow_data.copy() # If the dictionary is not copied , Then "dictionary changed size during iteration" error is shown😒
        for key, value in a.items() :
            if  self.student_name in value :
                value.remove(self.student_name)
                if len(value) == 0 :
                    del(Library.borrow_data[key])
                else :
                    pass
            else :
                pass
        print(f"All Books are returned by {self.student_name}")
#Write your code here    
s1 = Student("Alice",18101259)
s1.borrowbook("The Alchemist", "Hdw652")
print("===============")
print(s1)
print("===============")
print(Library.borrow_data)
print("===============")
s1.borrowbook("Wuthering Heights")
print("===============")
print(s1)
print("===============")
s2= Student("David",18141777)
s2.borrowbook("The Alchemist", "Hdw652")
print("===============")
s2.borrowbook("The Vampyre")
print("===============")
print(Library.borrow_data)
print("===============")
s1.returnAllBooks()
print("===============")
print(Library.borrow_data)


# It took me nearly 30 mins to solve this shit. 😓😖😤
# Out:
# A book is borrowed!
# 'The Alchemist' book with the unique id Hdw652 is borrowed by Alice(18101259)
# Number of books available for borrowing = 999
# ===============
# Library: XYZ
# Student Name: Alice ID: 18101259
# Books borrowed: The Alchemist
# ===============
# {'The Alchemist': ['Alice']}
# ===============
# A book is borrowed!
# 'Wuthering Heights' book is borrowed by Alice(18101259)
# Number of books available for borrowing = 998
# ===============
# Library: XYZ
# Student Name: Alice ID: 18101259
# Books borrowed: The Alchemist, Wuthering Heights
# ===============
# A book is borrowed!
# Sorry David ! The Alchemist book is borrowed by Alice
# ===============
# A book is borrowed!
# 'The Vampyre' book is borrowed by David(18141777)
# Number of books available for borrowing = 997
# ===============
# {'The Alchemist': ['Alice'], 'Wuthering Heights': ['Alice'], 'The Vampyre': ['David']}
# ===============
# All Books are returned by Alice
# ===============
# {'The Vampyre': ['David']}

# %%
# Task 15
class Player:
    database = {}
    playerNo = 0
    def __init__(self, name, team, jerseyNo):
        self.name = name
        self.team = team
        self.jerseyNo = jerseyNo
    def __str__(self):
        return "Name:{}\nTeam:{}\nJersey No:{}".format(self.name,self.team,self.jerseyNo)
class FootballPlayer (Player) :
    def __init__(self, name, team, jersey_no, goals, retirement = "Not yet retired") :
        super().__init__(name, team, jersey_no)
        self.retirement = retirement
        Player.playerNo += 1
        self.id = f'{Player.playerNo}'
        self.goals = goals
        a = name.split()
        for index in range(len(a)) :
            self.id += a[index][0]
        self.id += str(jersey_no)
        Player.database[self.id] = [self.name, self.team, self.jerseyNo, self.goals, self.retirement]
    def __str__(self) :
        print(super().__str__())
        print(f"Goal Scored: {self.goals}")
        return f"Retirement status: {self.retirement}"
    @classmethod
    def createPlayer(cls,  name, team, jersey_no, goals, retirement ) :
        return FootballPlayer(name, team, jersey_no, goals, retirement )
#Write your code here

print("Number of players:", Player.playerNo)
print("Player Database:", Player.database)
print("#################################")
p1 = FootballPlayer("Lionel Messi","Barcelona",10,231)
print("------Details of the player------")
print(p1)
print("#################################")
p2 = FootballPlayer("Cristiano Ronaldo","Juventus",7,215)
print("------Details of the player------")
print(p2)
print("#################################")
p3 = FootballPlayer.createPlayer("Miroslav Klose","Lazio",11, 71,"11 Aug,2014")
print("------Details of the player------")
print(p3)
print("#################################")
print("Number of players:",Player.playerNo)
print("Player Database:",Player.database)
# Out:
# Number of players: 0
# Player Database: {}
# #################################
# ------Details of the player------
# Name:Lionel Messi
# Team:Barcelona
# Jersey No:10
# Goal Scored: 231
# Retirement status: Not yet retired
# #################################
# ------Details of the player------
# Name:Cristiano Ronaldo
# Team:Juventus
# Jersey No:7
# Goal Scored: 215
# Retirement status: Not yet retired
# #################################
# ------Details of the player------
# Name:Miroslav Klose
# Team:Lazio
# Jersey No:11
# Goal Scored: 71
# Retirement status: 11 Aug,2014
# #################################
# Number of players: 3
# Player Database: {'1LM10': ['Lionel Messi', 'Barcelona', 10, 231, 'Not yet retired'], '2CR7': ['Cristiano Ronaldo', 'Juventus', 7, 215, 'Not yet retired'], '3MK11': ['Miroslav Klose', 'Lazio', 11, 71, '11 Aug,2014']}

# %%
# Task 17
class Magical_SportsPerson:
    database = {}
    playerNo = 0
    def __init__(self,name,team,jerseyNo):
        self.name = name
        self.team = team
        self.jerseyNo = jerseyNo
    
    def __str__(self):
        return "Name:{}\nTeam:{}\nJerseyNo:{}".format(self.name,     self.team, self.jerseyNo)
class Quidditch_Player (Magical_SportsPerson) :
    def __init__(self, name, team, jersey_no, goals, retirement = "Not yet retired") :
        super().__init__(name, team, jersey_no)
        self.retirement = retirement
        Magical_SportsPerson.playerNo += 1
        self.id = f'{Magical_SportsPerson.playerNo}'
        self.goals = goals
        a = name.split()
        for index in range(len(a)) :
            self.id += a[index][0]
        self.id += str(jersey_no)
        Magical_SportsPerson.database[self.id] = [self.name, self.team, self.jerseyNo, self.goals, self.retirement]
    def __str__(self) :
        print(super().__str__())
        print(f"Goal Scored: {self.goals}")
        return f"Retirement status: {self.retirement}"
    @classmethod
    def createPlayer(cls,  name, team, jersey_no, goals, retirement ) :
        return Quidditch_Player(name, team, jersey_no, goals, retirement )
#Write your code here

print("Number of players:",Magical_SportsPerson.playerNo)
print("Player Database:",Magical_SportsPerson.database)
print("#################################")
p1 = Quidditch_Player("Harry Potter","Gryffindor", 8, 523)
print("------Details of the player------")
print(p1)
print("#################################")
p2 = Quidditch_Player("Ronald Weasley","Gryffindor", 13, 5)
print("------Details of the player------")
print(p2)
print("#################################")
p3 = Quidditch_Player.createPlayer("George Weasley","Gryffindor", 12, 11, "11 Magical Year, 1886")
print("------Details of the player------")
print(p3)
print("#################################")
print("Number of players:",Magical_SportsPerson.playerNo)
print("Player Database:",Magical_SportsPerson.database)
# Out:
# Number of players: 0
# Player Database: {}
# #################################
# ------Details of the player------
# Name:Harry Potter
# Team:Gryffindor
# JerseyNo:8
# Goal Scored: 523
# Retirement status: Not yet retired
# #################################
# ------Details of the player------
# Name:Ronald Weasley
# Team:Gryffindor
# JerseyNo:13
# Goal Scored: 5
# Retirement status: Not yet retired
# #################################
# ------Details of the player------
# Name:George Weasley
# Team:Gryffindor
# JerseyNo:12
# Goal Scored: 11
# Retirement status: 11 Magical Year, 1886
# #################################
# Number of players: 3
# Player Database: {'1HP8': ['Harry Potter', 'Gryffindor', 8, 523, 'Not yet retired'], '2RW13': ['Ronald Weasley', 'Gryffindor', 13, 5, 'Not yet retired'], '3GW12': ['George Weasley', 'Gryffindor', 12, 11, '11 Magical Year, 1886']}

# %%
#Task 18
class User :
    def __init__(self, name, destination, type = 'Single') :
        self.name, self.destination, self.type = name, destination, type
        self.ride_status = False
        self.car_number = None
    def status(self) :
        if self.ride_status == False: 
            print(f"Status: {self.name} is looking for a {self.type.lower()} ride!")
        else: 
            print(f"Status: {self.name} boarded in car {self.car_number}")

class Uber :
    def __init__(self, number, type, *args) :
        self.number = number
        self.type = type
        self.routes = list(args)
    def details (self) :
        print(f"Car number: {self.number}")
        print(f"Type: {self.type}")
        print(f"Routes: {' --> '.join(self.routes)}")
    def pick (self, *args) :
        for index in range(len(args)):
            if self.type == args[index].type :
                if args[index].destination in self.routes :
                    print(f"{args[index].name} has been picked up.")
                    args[index].ride_status = True
                    args[index].car_number = self.number
                else :
                    print(f"{args[index].name}'s destination is different from this car's route.")
            else :
                print(f"{args[index].name} is looking for a different ride.")

user1 = User("Brooks", "Banani", "Shared")
user2 = User("Jocelyn", "Uttara")
user3 = User("Robert", "Gulshan", "Shared")
user4 = User("Langdon", "Mohakhali", "Shared")


user1.status()
user2.status()
user3.status()
user4.status()
print("----------------------------------")
car1 = Uber("0K32BH", "Shared", "Mohakhali", "Banani", "Nikunja", "Uttara")
car1.details()
print("----------------------------------")
car1.pick(user1,user2,user3,user4)
print("----------------------------------")
user1.status()
user2.status()
user3.status()
user4.status()
print("----------------------------------")
car2 = Uber("5GD2BD", "Single", "Uttara")
car3 = Uber("4T12FR", "Shared", "Gulshan", "Bashundhara")
car2.details()
car3.details()
print("----------------------------------")
car2.pick(user2, user3)
print("----------------------------------")
car3.pick(user3)
print("----------------------------------")
user2.status()
user3.status()
# Out:
# Status: Brooks is looking for a shared ride!
# Status: Jocelyn is looking for a single ride!
# Status: Robert is looking for a shared ride!
# Status: Langdon is looking for a shared ride!
# ----------------------------------
# Car number: 0K32BH
# Type: Shared
# Routes: Mohakhali --> Banani --> Nikunja --> Uttara
# ----------------------------------
# Brooks has been picked up.
# Jocelyn is looking for a different ride.
# Robert's destination is different from this car's route.
# Langdon has been picked up.
# ----------------------------------
# Status: Brooks boarded in car 0K32BH
# Status: Jocelyn is looking for a single ride!
# Status: Robert is looking for a shared ride!
# Status: Langdon boarded in car 0K32BH
# ----------------------------------
# Car number: 5GD2BD
# Type: Single
# Routes: Uttara
# Car number: 4T12FR
# Type: Shared
# Routes: Gulshan --> Bashundhara
# ----------------------------------
# Jocelyn has been picked up.
# Robert is looking for a different ride.
# ----------------------------------
# Robert has been picked up.
# ----------------------------------
# Status: Jocelyn boarded in car 5GD2BD
# Status: Robert boarded in car 4T12FR
